# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

BASE_DIR = os.getcwd()
os.chdir(BASE_DIR)
data = pd.read_csv('barGraph.csv')
data
# Out:
#                       Business  anticipation  enjoyment   sad  disgust  anger  \
# 0                Beauty & Spas             0        6.0   1.0        1    1.5
# 1          Burgers-Restaurants             0        1.0   2.0        1    2.0
# 2                        Pizza             0        6.0   1.0        0    4.0
# 3          Mexican Restaurants             0       33.0   3.0        3    9.0
# 4  Modern European-Restaurants             0      150.0  13.5       37   19.0
# 5                      Chinese             0       19.5   0.0        3    3.0
#
#    surprise  fear  trust
# 0         3     0      0
# 1         0     1      0
# 2         0     1      0
# 3         2     9      0
# 4        12    22      0
# 5         1     1      0

# %%
opacity = .4
bwidth = .35
index = np.arange(6)
plt.subplots()
plt.bar(index+width, [1, 5, 3, 4, 3, 2], bwidth, alpha=opacity, label='A')
plt.bar(index, [1, 0, 3, 0, 0, 0], bwidth, alpha=opacity, label='B')
plt.bar(index + 2 * width, [1, 0, 2, 0, 0, 4], bwidth, alpha=opacity, label='C')
plt.bar(index + 3 * width, [3, 0, 1, 0, 0, 4], bwidth, alpha=opacity, label='D')
plt.bar(index + 4 * width, [3, 0, 1, 8, 0, 4], bwidth, alpha=opacity, label='E')

# businesses = data['Business']
# plt.bar(1, [3], bwidth, label=biz_name)
# for b in businesses:
#     biz_name = b
#     biz_data = data[data['Business'] == biz_name].iloc[:, 1:]
#     plt.bar(6, [1,2,3], bwidth, label=biz_name)

    # plt.bar(6, biz_data, bwidth)
# index = np.arange(6)
# plt.subplots()

# for r in data.ix[0:, 'anticipation':]:
#     yvals = data[r]    
#     plt.bar(index, yvals, bwidth, label=yvals.name)

# print(data.ix[0:, 'anticipation':])
# xlabels = data['Business']
# xlabels
# for l in xlabels:
#     d = data[data['Business'] == l]
#     print(l)
#     plt.bar(index, [1], bwidth)
#     # print(d.iloc[:,1:])
#     # plt.bar(index, d.iloc[:,1:], bwidth)



# biz = data['Business']
# index = np.arange(8)
# data.ix[0:0, 'anticipation':]
# plt.bar(index, data['anticipation'], bwidth, alpha=opacity, color='b', label='Beauty & Spas')
# plt.bar(index + bwidth, data['enjoyment'], bwidth, label='Burgers-Restaurants')
# plt.bar(index + bwidth, data['sad'], bwidth, label='Pizza')
# plt.bar(index + bwidth, data['disgust'], bwidth, label='Mexican Rest')
# plt.bar(index + bwidth, data['anger'], bwidth, label='Modern European-Restaurants')
# plt.bar(index + bwidth, data['surprise'], bwidth)
# plt.bar(index + bwidth, data['fear'], bwidth)
# plt.bar(index + bwidth, data['trust'], bwidth)
# # plt.set_xticklabels(biz)
# # plt.set_xticks(index + bwidth / 2)

# plt.xlabel('Business')
# plt.ylabel('Emotion')
# plt.title('Emotion by Business')
# plt.legend(data.columns[1:])

# plt.show()
# data.ix[0:0, 'anticipation':]
# Out:
# <Container object of 6 artists>
